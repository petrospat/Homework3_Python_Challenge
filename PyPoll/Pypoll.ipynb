# %%
import os
import csv
import numpy as np
import subprocess

row = []
row_count = 0
candidates = []

csvpath = os.path.join('Resources', 'election_data.csv')

with open(csvpath, newline='') as csvfile:

    # CSV reader specifies delimiter and variable that holds contents
    csvreader = csv.reader(csvfile, delimiter=',')

    #print(csvreader)

    # Read the header row first (skip this step if there is no header)
    csv_header = next(csvreader)
    #print(f"CSV Header: {csv_header}")
    for row in csvreader:
        #print(row)
        row_count = row_count+1
        candidates.append(row[2])
        
print("Election Results")
print("-------------------------")
print(f"Total Votes: {row_count}")
print("-------------------------")
# Out:
# Total Votes: 3521001

# %%
#lst_cand = []
lst_cand = np.unique(candidates)

#print(f"{lst_cand[:,None]}")
#print('\n'.join(lst_cand))
# Out:
# Correy
# Khan
# Li
# O'Tooley

# %%
#list(candidates)
# Out:
# ['Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Li',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  "O'Tooley",
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  "O'Tooley",
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Li',
#  'Correy',
#  'Correy',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Li',
#  'Li',
#  'Correy',
#  'Correy',
#  'Li',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Li',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Correy',
#  "O'Tooley",
#  'Khan',
#  'Li',
#  'Li',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  "O'Tooley",
#  'Li',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Li',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Li',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Li',
#  "O'Tooley",
#  'Khan',
#  'Li',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Correy',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Li',
#  'Li',
#  'Li',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Li',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  "O'Tooley",
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Li',
#  "O'Tooley",
#  'Correy',
#  'Correy',
#  'Correy',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  "O'Tooley",
#  'Li',
#  'Correy',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  "O'Tooley",
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Li',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Li',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Li',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Li',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Li',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Correy',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  "O'Tooley",
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  "O'Tooley",
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Li',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Li',
#  'Li',
#  'Khan',
#  'Correy',
#  'Li',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Li',
#  'Correy',
#  'Li',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Correy',
#  'Khan',
#  'Li',
#  'Khan',
#  'Khan',
#  "O'Tooley",
#  'Correy',
#  'Correy',
#  'Correy',
#  'Correy',
#  'Khan',
#  'Khan',
#  'Li',
#  'Khan',
#  'Correy',
#  'Correy',
#  'Khan',
#  "O'Tooley",
#  ...]

# %%
res =[]
perc = []
for cand in lst_cand:
    perc = (list(candidates).count(cand)/row_count)
    z=[cand,list(candidates).count(cand),"{:.1%}".format(perc)]
    #print(cand,list(candidates).count(cand),"{:.1%}".format(list(candidates).count(cand)/row_count))
    res.append(z)   
#print('\n'.join(res))
#tip: use sorted function
#sorted(student_tuples, key=lambda student: student[2]
#print(sorted(res, key=lambda st:st[1], reverse =True))
l = sorted(res, key=lambda st:st[1], reverse =True)
#print('\n'.join(l))
#print(f"{l[:,None]}")
#print (l)[1:-1]
#print(*l,sep='\n')
print("-------------------------")
print(f"{l[0][0]}: {l[0][2]} ({l[0][1]})")
print(f"{l[1][0]}: {l[1][2]} ({l[1][1]})")
print(f"{l[2][0]}: {l[2][2]} ({l[2][1]})")
print(f"{l[3][0]}: {l[3][2]} ({l[3][1]})")
print("-------------------------")
# Out:
# Khan: 63.0% (2218231)
# Correy: 20.0% (704200)
# Li: 14.0% (492940)
# O'Tooley: 3.0% (105630)

# %%
#winner = max(res, key=lambda item: int(item[1]))
#print(max(res, key=lambda item: int(item[1])))
print(f"Winner: {l[0][0]}")
# Out:
# Winner: Khan

# %%
with open("output.txt", "w+") as output:
    output.write("Election Results\n")
    output.write("-------------------------\n")
    output.write(f"Total Votes: {row_count}\n")
    output.write("-------------------------\n")
    #output.write('\n'.join(lst_cand))
    output.write(f"{l[0][0]}: {l[0][2]} ({l[0][1]})\n")
    output.write(f"{l[1][0]}: {l[1][2]} ({l[1][1]})\n")
    output.write(f"{l[2][0]}: {l[2][2]} ({l[2][1]})\n")
    output.write(f"{l[3][0]}: {l[3][2]} ({l[3][1]})\n")
    output.write("-------------------------\n")
    output.write(f"Winner: {l[0][0]}\n")
    output.write("-------------------------\n")

# %%
import os
import csv
import numpy as np


row = []
row_count = 0
candidates = []
res =[]
perc = []

csvpath = os.path.join('Resources', 'election_data.csv')

with open(csvpath, newline='') as csvfile:

    # CSV reader specifies delimiter and variable that holds contents
    csvreader = csv.reader(csvfile, delimiter=',')

    #print(csvreader)

    # Read the header row first (skip this step if there is no header)
    csv_header = next(csvreader)
    #print(f"CSV Header: {csv_header}")
    for row in csvreader:
        #print(row)
        row_count = row_count+1
        candidates.append(row[2])
        

lst_cand = np.unique(candidates)

for cand in lst_cand:
    perc = (list(candidates).count(cand)/row_count)
    z=[cand,list(candidates).count(cand),"{:.1%}".format(perc)]
    #print(cand,list(candidates).count(cand),"{:.1%}".format(list(candidates).count(cand)/row_count))
    res.append(z)

l = sorted(res, key=lambda st:st[1], reverse =True)

print("Election Results")
print("-------------------------")
print(f"Total Votes: {row_count}")
print("-------------------------")
print(f"{l[0][0]}: {l[0][2]} ({l[0][1]})")
print(f"{l[1][0]}: {l[1][2]} ({l[1][1]})")
print(f"{l[2][0]}: {l[2][2]} ({l[2][1]})")
print(f"{l[3][0]}: {l[3][2]} ({l[3][1]})")
print("-------------------------")
print(f"Winner: {l[0][0]}")
print("-------------------------")

with open("output.txt", "w+") as output:
    output.write("Election Results\n")
    output.write("-------------------------\n")
    output.write(f"Total Votes: {row_count}\n")
    output.write("-------------------------\n")
    #output.write('\n'.join(lst_cand))
    output.write(f"{l[0][0]}: {l[0][2]} ({l[0][1]})\n")
    output.write(f"{l[1][0]}: {l[1][2]} ({l[1][1]})\n")
    output.write(f"{l[2][0]}: {l[2][2]} ({l[2][1]})\n")
    output.write(f"{l[3][0]}: {l[3][2]} ({l[3][1]})\n")
    output.write("-------------------------\n")
    output.write(f"Winner: {l[0][0]}\n")
    output.write("-------------------------\n")
# Out:
# Election Results
# -------------------------
# Total Votes: 3521001
# -------------------------
# Khan: 63.0% (2218231)
# Correy: 20.0% (704200)
# Li: 14.0% (492940)
# O'Tooley: 3.0% (105630)
# -------------------------
# Winner: Khan
# -------------------------
